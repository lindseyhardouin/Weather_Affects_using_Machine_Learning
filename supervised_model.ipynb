# %%
# Import the modules

import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.metrics import accuracy_score, classification_report
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

import warnings
warnings.filterwarnings('ignore')

# %%
# Read the CSV file from the Resources folder into a Pandas DataFrame

data = pd.read_csv("data/neural_network_df.csv")


# Review the DataFrame

data.head()
# Out:
#             state  temperature    precip   humidity  visibility     pressure  \
# 0         Florida    18.531100  0.124402  60.258373    9.966507  1018.114833
# 1         Arizona    17.733333  0.000000  31.533333   10.000000  1019.066667
# 2  South Carolina    12.875000  0.000000  67.291667   10.000000  1017.041667
# 3         Georgia    12.032258  0.000000  65.935484   10.000000  1019.129032
# 4          Nevada    11.625000  2.237500  46.250000    9.500000  1018.000000
#
#    cloudcover  heatindex  dewpoint  windchill   windgust  feelslike  \
# 0   28.937799  17.062201  8.641148  16.239234  17.559809  16.377990
# 1    8.266667  13.133333 -3.933333  12.666667   7.133333  12.666667
# 2   21.708333   9.666667  3.750000   8.583333  12.916667   8.583333
# 3    9.225806   7.354839  1.096774   5.322581  15.322581   5.322581
# 4   29.375000   7.250000 -5.000000   6.250000  11.375000   6.250000
#
#      mintemp    maxtemp    avgtemp  totalsnow   sunhour   blmn
# 0  14.363636  18.531100  16.593301      0.000  7.513397  18.34
# 1   8.733333  17.733333  13.066667      0.000  8.700000  18.34
# 2   7.083333  12.875000  10.166667      0.000  8.287500  18.34
# 3   3.741935  12.032258   7.870968      0.000  8.700000  18.34
# 4   2.375000  11.625000   8.000000      1.225  7.400000  18.34

# %%
# Transform the Card Type column using get_dummies()

dummies = pd.get_dummies(data["state"])


# Display sample data

dummies.head()
# Out:
#    Arizona  Florida  Georgia  Nevada  South Carolina
# 0        0        1        0       0               0
# 1        1        0        0       0               0
# 2        0        0        0       0               1
# 3        0        0        1       0               0
# 4        0        0        0       1               0

# %%
# Concatenate the df_shopping_transformed and the card_dummies DataFrames

data = pd.concat([data, dummies], axis=1)


# drop the original catrgoricl column

data = data.drop(columns="state")


# Display sample data

data.head()
# Out:
#    temperature    precip   humidity  visibility     pressure  cloudcover  \
# 0    18.531100  0.124402  60.258373    9.966507  1018.114833   28.937799
# 1    17.733333  0.000000  31.533333   10.000000  1019.066667    8.266667
# 2    12.875000  0.000000  67.291667   10.000000  1017.041667   21.708333
# 3    12.032258  0.000000  65.935484   10.000000  1019.129032    9.225806
# 4    11.625000  2.237500  46.250000    9.500000  1018.000000   29.375000
#
#    heatindex  dewpoint  windchill   windgust  ...    maxtemp    avgtemp  \
# 0  17.062201  8.641148  16.239234  17.559809  ...  18.531100  16.593301
# 1  13.133333 -3.933333  12.666667   7.133333  ...  17.733333  13.066667
# 2   9.666667  3.750000   8.583333  12.916667  ...  12.875000  10.166667
# 3   7.354839  1.096774   5.322581  15.322581  ...  12.032258   7.870968
# 4   7.250000 -5.000000   6.250000  11.375000  ...  11.625000   8.000000
#
#    totalsnow   sunhour   blmn  Arizona  Florida  Georgia  Nevada  \
# 0      0.000  7.513397  18.34        0        1        0       0
# 1      0.000  8.700000  18.34        1        0        0       0
# 2      0.000  8.287500  18.34        0        0        0       0
# 3      0.000  8.700000  18.34        0        0        1       0
# 4      1.225  7.400000  18.34        0        0        0       1
#
#    South Carolina
# 0               0
# 1               0
# 2               1
# 3               0
# 4               0
#
# [5 rows x 22 columns]

# %%
# Separate the data into labels and features

# Separate the y variable, the labels

y = data["blmn"]


y.head()
# Out:
# 0    18.34
# 1    18.34
# 2    18.34
# 3    18.34
# 4    18.34
# Name: blmn, dtype: float64

# %%
# Separate the X variable, the features

X = data.drop(columns="blmn")


X.head()
# Out:
#    temperature    precip   humidity  visibility     pressure  cloudcover  \
# 0    18.531100  0.124402  60.258373    9.966507  1018.114833   28.937799
# 1    17.733333  0.000000  31.533333   10.000000  1019.066667    8.266667
# 2    12.875000  0.000000  67.291667   10.000000  1017.041667   21.708333
# 3    12.032258  0.000000  65.935484   10.000000  1019.129032    9.225806
# 4    11.625000  2.237500  46.250000    9.500000  1018.000000   29.375000
#
#    heatindex  dewpoint  windchill   windgust  ...    mintemp    maxtemp  \
# 0  17.062201  8.641148  16.239234  17.559809  ...  14.363636  18.531100
# 1  13.133333 -3.933333  12.666667   7.133333  ...   8.733333  17.733333
# 2   9.666667  3.750000   8.583333  12.916667  ...   7.083333  12.875000
# 3   7.354839  1.096774   5.322581  15.322581  ...   3.741935  12.032258
# 4   7.250000 -5.000000   6.250000  11.375000  ...   2.375000  11.625000
#
#      avgtemp  totalsnow   sunhour  Arizona  Florida  Georgia  Nevada  \
# 0  16.593301      0.000  7.513397        0        1        0       0
# 1  13.066667      0.000  8.700000        1        0        0       0
# 2  10.166667      0.000  8.287500        0        0        0       0
# 3   7.870968      0.000  8.700000        0        0        1       0
# 4   8.000000      1.225  7.400000        0        0        0       1
#
#    South Carolina
# 0               0
# 1               0
# 2               1
# 3               0
# 4               0
#
# [5 rows x 21 columns]

# %%
# Check the balance of our target values

y.value_counts().sort_values()
# Out:
# 19.99     3
# 21.33     5
# 27.00     5
# 20.96     5
# 19.17     5
#          ..
# 21.07     5
# 23.41    10
# 26.10    10
# 24.84    10
# 19.35    10
# Name: blmn, Length: 76, dtype: int64

# %%
# Import the train_test_learn module

from sklearn.model_selection import train_test_split


# Split the data using train_test_split
# Assign a random_state of 1 to the function

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Import the LogisticRegression module from SKLearn

from sklearn.linear_model import LogisticRegression


# Instantiate the Logistic Regression model
# Assign a random_state parameter of 1 to the model

logistic_regression_model = LogisticRegression(random_state=1)


# Fit the model using training data

lr_model = logistic_regression_model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-50d6073ff9f2> in <module>
#      12 # Fit the model using training data
#      13
# ---> 14 lr_model = logistic_regression_model.fit(X_train, y_train)
#
# ~\anaconda3\envs\pyviz\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1345                                    order="C",
#    1346                                    accept_large_sparse=solver != 'liblinear')
# -> 1347         check_classification_targets(y)
#    1348         self.classes_ = np.unique(y)
#    1349
#
# ~\anaconda3\envs\pyviz\lib\site-packages\sklearn\utils\multiclass.py in check_classification_targets(y)
#     181     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
#     182                       'multilabel-indicator', 'multilabel-sequences']:
# --> 183         raise ValueError("Unknown label type: %r" % y_type)
#     184
#     185
#
# ValueError: Unknown label type: 'continuous'
