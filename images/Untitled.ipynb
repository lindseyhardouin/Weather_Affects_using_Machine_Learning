# %%
import pandas as pd
import hvplot
from pathlib import Path

# %%
#Import location information from weather data

locations = pd.read_csv(
    Path('../data/cleaned_data/df_weather_data_updated.csv')
)

locations.head().transpose()
# Out:
#                                      0                 1  \
# Unnamed: 0                           0                 1
# Unnamed: 0.1                         0                 1
# Unnamed: 0.1.1                     0.0               1.0
# request.type                   Zipcode           Zipcode
# request.query                    34231             34201
# request.language                    en                en
# request.unit                         m                 m
# location.name                 Sarasota         Bradenton
# location.country                   USA               USA
# location.region                Florida           Florida
# location.lat                    27.272            27.403
# location.lon                   -82.517           -82.477
# location.timezone_id  America/New_York  America/New_York
# location.utc_offset               -5.0              -5.0
# temperature                         23                24
# ...

# %%
locations = locations[locations['date'] == '2021-01-01']
locations = locations.drop(locations.columns[0:2], axis=1, inplace=True)
locations
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20168/30872192.py in <module>
# ----> 1 locations = locations[locations['date'] == '2021-01-01']
#       2 locations = locations.drop(locations.columns[0:2], axis=1, inplace=True)
#       3 locations
#
# TypeError: 'NoneType' object is not subscriptable
